# %% [markdown]
# # Line Extending Game Gym Demo

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nsai_experiments import line_extending_game_tools as lgt
from nsai_experiments import line_extending_game_gym as leg_gym

import gymnasium as gym

# %%
my_gym = leg_gym.WindowlessLineExtendingGameEnv()
lgt.display_grid(my_gym.reset(seed=47)[0])
print()
lgt.display_grid((step_results := my_gym.step(11))[0])
print(step_results[1:])
for i in range(98):
    (step_results := my_gym.step(0))
print(step_results[1:])
lgt.display_grid((step_results := my_gym.step(11))[0])
print(step_results[1:])
# Out:
# - - - - - - - - - -
# - - - - - - - - - -
# x x x - - - - - - -
# - - - - - - - - - -
# - - - - - - - x - -
# - - - - - - - - - x
# - - - - - - - - - -
# - - - - - - - - - -
# x - - - - - - - - -
# - - - - - - - - - -
#
# - - - - - - - - - -
# - x - - - - - - - -
# x x x - - - - - - -
# - - - - - - - - - -
# - - - - - - - x - -
# - - - - - - - - - x
# - - - - - - - - - -
# - - - - - - - - - -
# x - - - - - - - - -
# - - - - - - - - - -
# (0, False, False, {})
# (0, False, False, {})
# - - - - - - - - - -
# - - - - - - - - - -
# x x x - - - - - - -
# - - - - - - - - - -
# - - - - - - - x - -
# - - - - - - - - - x
# - - - - - - - - - -
# - - - - - - - - - -
# x - - - - - - - - -
# - - - - - - - - - -
# (np.int64(93), False, True, {})

# %%
my_gym = leg_gym.WindowlessLineExtendingGameEnv()
lgt.display_grid(my_gym.reset(seed=47)[0])
for i in range(23, 30):
    step_results = my_gym.step(i)
lgt.display_grid(step_results[0])
print(step_results[1:])
# Out:
# - - - - - - - - - -
# - - - - - - - - - -
# x x x - - - - - - -
# - - - - - - - - - -
# - - - - - - - x - -
# - - - - - - - - - x
# - - - - - - - - - -
# - - - - - - - - - -
# x - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# - - - - - - - - - -
# x x x x x x x x x x
# - - - - - - - - - -
# - - - - - - - x - -
# - - - - - - - - - x
# - - - - - - - - - -
# - - - - - - - - - -
# x - - - - - - - - -
# - - - - - - - - - -
# (np.int64(100), True, False, {})

# %%
gym.pprint_registry()
# Out:
# ===== classic_control =====
# Acrobot-v1                     CartPole-v0                    CartPole-v1
# MountainCar-v0                 MountainCarContinuous-v0       Pendulum-v1
# ===== phys2d =====
# phys2d/CartPole-v0             phys2d/CartPole-v1             phys2d/Pendulum-v0
# ===== box2d =====
# BipedalWalker-v3               BipedalWalkerHardcore-v3       CarRacing-v3
# LunarLander-v3                 LunarLanderContinuous-v3
# ===== toy_text =====
# Blackjack-v1                   CliffWalking-v0                FrozenLake-v1
# FrozenLake8x8-v1               Taxi-v3
# ===== tabular =====
# tabular/Blackjack-v0           tabular/CliffWalking-v0
# ===== mujoco =====
# Ant-v2                         Ant-v3                         Ant-v4
# Ant-v5                         HalfCheetah-v2                 HalfCheetah-v3
# HalfCheetah-v4                 HalfCheetah-v5                 Hopper-v2
# Hopper-v3                      Hopper-v4                      Hopper-v5
# ...
